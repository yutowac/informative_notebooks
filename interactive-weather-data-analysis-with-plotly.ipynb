# %% [markdown]
# # Interactive Weather Data Analysis with Plotly 🌦️📊

# %% [markdown]
# Welcome to Exploratory Data Analysis with Plotly! In this notebook, we will embark on an interactive journey to explore a rich dataset containing daily weather information for capital cities around the world. This dataset is packed with over 40 diverse weather-related features, making it a goldmine for climate trend analysis and global weather pattern identification.

# %% [markdown]
# ## Objective:
#
# Our primary objective is to conduct an engaging and interactive exploratory data analysis (EDA) using the powerful Plotly library while keeping this notebook beginner-friendly. Through interactive visualizations, we aim to unlock insights from the data, understand weather trends, and reveal relationships between different weather parameters.
#
# In this journey of data exploration, we'll harness the capabilities of Plotly to create dynamic and interactive plots. These visualizations will not only make the analysis more informative but also user-friendly for individuals with varying levels of data analysis experience.

# %% [markdown]
# So, let's embark on this data-driven adventure and start unraveling the fascinating world of weather data through interactive exploration! 🌟

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/global-weather-repository/GlobalWeatherRepository.csv

# %%
# Import necessary libraries

import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# - Plotly Express is a high-level Python library for creating interactive visualizations.
# - The pprint module stands for "pretty-printing." It is used for formatting complex or nested data structure
# - IPython environments to control the display of HTML and other content.

# %% [markdown]
# # Basic Data Exploration

# %%
weather = pd.read_csv("/kaggle/input/global-weather-repository/GlobalWeatherRepository.csv")

# %%
# This will display all columns without truncation
pd.set_option('display.max_columns', None)

# %%
weather.sample(4)
# Out:
#         country location_name  latitude  longitude          timezone  \
# 27030  Pakistan     Islamabad     33.70      73.17      Asia/Karachi
# 10569  Dominica        Roseau     15.30     -61.40  America/Dominica
# 11226    Turkey         Yaren     39.55      27.62   Europe/Istanbul
# 10938   Burundi     Bujumbura     -3.38      29.36  Africa/Bujumbura
#
#        last_updated_epoch      last_updated  temperature_celsius  \
# 27030          1705688100  2024-01-19 23:15                  9.3
# 10569          1697921100  2023-10-21 16:45                 26.0
# 11226          1698180300  2023-10-24 23:45                 16.0
# 10938          1698093900  2023-10-23 22:45                 24.5
#
#        temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 27030                    48.8  Partly cloudy       6.0       9.7           51
# 10569                    78.8  Partly cloudy       2.5       4.0          150
# 11226                    60.8          Clear       2.2       3.6           10
# 10938                    76.1          Clear       2.2       3.6           70
#
#       wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  \
# 27030             NE       1017.0        30.05       0.00       0.00
# 10569            SSE       1007.0        29.74       0.51       0.02
# 11226              N       1015.0        29.97       0.00       0.00
# 10938            ENE       1009.0        29.80       0.00       0.00
#
#        humidity  cloud  feels_like_celsius  feels_like_fahrenheit  \
# 27030        34     47                 7.9                   46.1
# 10569       100     75                28.3                   83.0
# 11226        68      0                16.0                   60.8
# 10938        66      4                26.0                   78.8
#
#        visibility_km  visibility_miles  uv_index  gust_mph  gust_kph  \
# 27030           10.0               6.0       1.0      12.7      20.4
# 10569           10.0               6.0       6.0      12.2      19.7
# 11226           10.0               6.0       1.0       2.3       3.7
# 10938           10.0               6.0       1.0       2.5       4.0
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 27030                       4699.7                0.0
# 10569                        377.2               33.3
# 11226                        340.5               25.4
# 10938                        894.6                7.1
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 27030                         153.5                         16.2
# 10569                           4.6                          2.4
# 11226                           8.4                          1.8
# 10938                           7.5                          1.2
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 27030              280.2             364.0                         6
# 10569                2.5               3.6                         1
# 11226              103.9             138.5                         4
# 10938               33.2              93.8                         2
#
#        air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 27030                          10  07:11 AM  05:25 PM  12:06 PM  01:14 AM
# 10569                           1  05:59 AM  05:42 PM  12:17 PM  11:41 PM
# 11226                          10  07:29 AM  06:18 PM  04:13 PM  01:51 AM
# 10938                           3  05:41 AM  05:53 PM  01:17 PM  12:59 AM
#
#             moon_phase  moon_illumination
# 27030   Waxing Gibbous                 59
# 10569  Waxing Crescent                 37
# 11226   Waxing Gibbous                 71
# 10938   Waxing Gibbous                 60

# %%
numeric = weather.describe(include=np.number)
categoric = weather.describe(include="object")

# %%
#Summary Statistic for Numerical features
numeric
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  37035.000000  37035.000000        3.703500e+04         37035.000000
# mean      19.301356     21.779966        1.701722e+09            19.024817
# std       24.526639     65.687372        4.946333e+06            10.764854
# min      -41.300000   -175.200000        1.693301e+09           -41.900000
# 25%        3.750000     -6.840000        1.697317e+09            12.000000
# 50%       17.250000     23.240000        1.701977e+09            22.000000
# 75%       41.320000     49.880000        1.706033e+09            27.000000
# max       64.100000    179.220000        1.710089e+09            45.400000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            37035.000000  37035.000000  37035.000000  37035.000000
# mean                66.244501      7.378042     11.876576    161.954529
# std                 19.376848      5.167539      8.318227    106.708671
# min                -43.400000      2.200000      3.600000      1.000000
# 25%                 53.600000      3.800000      6.100000     70.000000
# 50%                 71.600000      5.600000      9.000000    150.000000
# 75%                 80.600000     10.500000     16.900000    250.000000
# max                113.700000     91.900000    148.000000    360.000000
#
#         pressure_mb   pressure_in     precip_mm     precip_in      humidity  \
# count  37035.000000  37035.000000  37035.000000  37035.000000  37035.000000
# mean    1013.979344     29.942124      0.133508      0.005070     70.942946
# std        7.515276      0.221825      0.597546      0.023591     20.936170
# min      958.000000     28.290000      0.000000      0.000000      3.000000
# 25%     1010.000000     29.830000      0.000000      0.000000     60.000000
# 50%     1013.000000     29.910000      0.000000      0.000000     75.000000
# 75%     1018.000000     30.060000      0.020000      0.000000     87.000000
# max     1074.000000     31.710000     31.000000      1.220000    100.000000
#
#               cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# count  37035.000000        37035.000000           37035.000000   37035.000000
# mean      37.518267           19.820305              67.670166       9.550069
# std       33.895632           13.202871              23.761742       2.666435
# min        0.000000          -49.100000             -56.300000       0.000000
# 25%        0.000000           11.200000              52.200000      10.000000
# 50%       25.000000           22.400000              72.400000      10.000000
# 75%       75.000000           29.500000              85.200000      10.000000
# max      100.000000           73.600000             164.400000      32.000000
#
#        visibility_miles      uv_index     gust_mph      gust_kph  \
# count      37035.000000  37035.000000  37035.00000  37035.000000
# mean           5.635534      2.454219     12.32324     19.833269
# std            1.673395      2.554642      7.41429     11.932210
# min            0.000000      1.000000      0.00000      0.000000
# 25%            6.000000      1.000000      6.70000     10.800000
# 50%            6.000000      1.000000     11.00000     17.700000
# 75%            6.000000      4.000000     16.30000     26.300000
# max           19.000000     13.000000     96.40000    155.200000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 37035.000000       37035.000000
# mean                    584.915723          42.699263
# std                    1409.804573          32.208470
# min                      96.800000           0.000000
# 25%                     233.700000          17.700000
# 50%                     290.400000          40.100000
# 75%                     454.000000          62.200000
# max                   41870.102000         555.000000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  37035.000000                 37035.000000
# mean                      14.643759                     8.337149
# std                       27.038277                    22.882550
# min                        0.000000                     0.000000
# 25%                        1.100000                     0.500000
# 50%                        4.500000                     1.900000
# 75%                       15.900000                     6.400000
# max                      575.800000                   557.000000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       37035.000000      37035.000000              37035.000000
# mean           25.912823         46.472078                  1.626947
# std            65.342583        108.751417                  1.080218
# min             0.500000          0.500000                  1.000000
# 25%             2.600000          4.700000                  1.000000
# 50%             7.600000         13.100000                  1.000000
# 75%            23.400000         40.200000                  2.000000
# max          1558.800000       3566.400000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                 37035.00000       37035.000000
# mean                      2.48816          51.380559
# std                       2.71018          35.199598
# min                       1.00000           0.000000
# 25%                       1.00000          17.000000
# 50%                       1.00000          52.000000
# 75%                       2.00000          86.000000
# max                      10.00000         100.000000

# %%
#Summary Statistic for Categorical features
categoric
# Out:
#          country location_name     timezone      last_updated condition_text  \
# count      37035         37035        37035             37035          37035
# unique       185           220          183              5510             51
# top     Bulgaria       Tbilisi  Europe/Rome  2023-09-14 16:30  Partly cloudy
# freq         515           191          570                47          14247
#
#        wind_direction   sunrise    sunset     moonrise     moonset  \
# count           37035     37035     37035        37035       37035
# unique             16       337       369         1441        1441
# top                 N  06:21 AM  06:02 PM  No moonrise  No moonset
# freq             4158       415       418         1310        1169
#
#             moon_phase
# count            37035
# unique               8
# top     Waning Gibbous
# freq              8575

# %% [markdown]
# # Plotly LineChart

# %%
# Temperature Trends
trend = weather.query("country in ['Thailand', 'New Zealand', 'Spain', 'United States of America']")

# %%
# Selected Countires Temperature Trends
fig = px.line(trend,x='last_updated',y='temperature_celsius',title="Temperature Trends",color="country",markers=True,text="humidity")
fig.update_xaxes(title="Last Updated")
fig.update_yaxes(title="Temperature (°C)")

# Customize the text labels
fig.update_traces(
    #texttemplate='%{y}°C<br>Humidity: %{text}%',  # Customized text label format
    textposition='top center',  # Adjust text label position
    textfont=dict(size=12),  # Adjust text label font size
)

# Customize the legend
fig.update_layout(
    legend_title_text='Country',# Change the legend title
    height=600,
    width=1000
)


# Customize the line and marker styles
fig.update_traces(
    line=dict(width=3),  # Adjust line width
    marker=dict(size=12, line=dict(width=1, color='DarkSlateGrey')),  # Adjust marker size and outline
)


fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7504cfe4-cdb1-4009-92bd-68d667659442" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7504cfe4-cdb1-4009-92bd-68d667659442")) {                    Plotly.newPlot(                        "7504cfe4-cdb1-4009-92bd-68d667659442",                        [{"hovertemplate":"country=Thailand\u003cbr\u003elast_updated=%{x}\u003cbr\u003etemperature_celsius=%{y}\u003cbr\u003ehumidity=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thailand","line":{"color":"#636efa","dash":"solid","width":3},"marker":{"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":12},"mode":"lines+text+markers","name":"Thailand","orientation":"v","showlegend":true,"text":[63.0,56.0,94.0,71.0,100.0,94.0,100.0,89.0,94.0,74.0,100.0,74.0,100.0,84.0,100.0,74.0,94.0,84.0,100.0,70.0,94.0,84.0,100.0,70.0,94.0,94.0,100.0,94.0,94.0,84.0,94.0,79.0,100.0,89.0,100.0,84.0,100.0,79.0,100.0,89.0,100.0,100.0,94.0,100.0,84.0,100.0,89.0,100.0,94.0,94.0,84.0,100.0,89.0,99.0,89.0,99.0,94.0,98.0,94.0,99.0,100.0,99.0,89.0,98.0,94.0,100.0,84.0,98.0,79.0,99.0,79.0,98.0,94.0,98.0,94.0,98.0,94.0,99.0,89.0,98.0,94.0,99.0,84.0,97.0,89.0,98.0,94.0,98.0,89.0,98.0,94.0,98.0,79.0,99.0,84.0,98.0,79.0,98.0,79.0,97.0,79.0,97.0,89.0,98.0,84.0,98.0,75.0,98.0,94.0,97.0,84.0,98.0,89.0,96.0,84.0,98.0,84.0,98.0,89.0,98.0,84.0,98.0,89.0,98.0,84.0,98.0,79.0,97.0,79.0,97.0,79.0,96.0,75.0,98.0,89.0,98.0,89.0,97.0,84.0,98.0,84.0,97.0,79.0,97.0,84.0,96.0,89.0,100.0,74.0,97.0,79.0,93.0,89.0,84.0,69.0,80.0,69.0,87.0,61.0,92.0,65.0,94.0,74.0,94.0,70.0,95.0,74.0,91.0,70.0,92.0,61.0,92.0,84.0,90.0,70.0,92.0,69.0,93.0,70.0,91.0,66.0,93.0,73.0,92.0,89.0,92.0,84.0,97.0,79.0,88.0,79.0,96.0,79.0,90.0,79.0,97.0,74.0,97.0,79.0,87.0,79.0,85.0,79.0,86.0,74.0,89.0,74.0,80.0,74.0,75.0,74.0,78.0,70.0,79.0,70.0,70.0,66.0,60.0,69.0,73.0,64.0,81.0,47.0,76.0,50.0,83.0,53.0,87.0,69.0,83.0,69.0,74.0,65.0,74.0,65.0,74.0,66.0,69.0,62.0,71.0,44.0,70.0,62.0,70.0,62.0,74.0,70.0,73.0,62.0,70.0,62.0,71.0,66.0,73.0,70.0,70.0,70.0,71.0,74.0,70.0,74.0,85.0,79.0,90.0,84.0,72.0,66.0,65.0,66.0,66.0,70.0,58.0,74.0,59.0,66.0,50.0,66.0,50.0,84.0,50.0,66.0,54.0,62.0,64.0,70.0,71.0,69.0,84.0,61.0,87.0,65.0,80.0,70.0,98.0,65.0,92.0,62.0,94.0,70.0,69.0,70.0,50.0,79.0,56.0,79.0,53.0,79.0,45.0,84.0,42.0,84.0,37.0,84.0,41.0,89.0,42.0,84.0,49.0,79.0,64.0,66.0,66.0,69.0,57.0,65.0,47.0,40.0,42.0,74.0,40.0,79.0,45.0,79.0,43.0,79.0,41.0,79.0,41.0,84.0,41.0,75.0,34.0,79.0,42.0,84.0,38.0,79.0,54.0,79.0,61.0,79.0,44.0,75.0,58.0,66.0,51.0,79.0,45.0,79.0,58.0,79.0,76.0,79.0,51.0,75.0,32.0,75.0,30.0,79.0,30.0,84.0,35.0,84.0,45.0,75.0,70.0,79.0,45.0,75.0],"x":["2023-08-29 16:45","2023-08-29 16:45","2023-08-30 10:00","2023-08-30 10:00","2023-08-31 06:45","2023-08-31 06:45","2023-09-01 06:45","2023-09-01 06:45","2023-09-02 06:30","2023-09-02 06:45","2023-09-03 06:45","2023-09-03 06:45","2023-09-04 06:30","2023-09-04 06:30","2023-09-05 06:30","2023-09-05 06:30","2023-09-06 06:15","2023-09-06 06:15","2023-09-07 06:00","2023-09-07 06:00","2023-09-08 06:00","2023-09-08 06:00","2023-09-09 05:45","2023-09-09 06:00","2023-09-10 05:45","2023-09-10 06:00","2023-09-11 05:45","2023-09-11 05:45","2023-09-12 06:00","2023-09-12 06:00","2023-09-13 05:45","2023-09-13 05:45","2023-09-14 21:30","2023-09-14 21:30","2023-09-15 05:30","2023-09-15 05:30","2023-09-16 05:30","2023-09-16 05:30","2023-09-17 05:30","2023-09-17 05:30","2023-09-18 05:30","2023-09-18 05:30","2023-09-19 05:30","2023-09-20 05:30","2023-09-20 05:15","2023-09-21 05:30","2023-09-21 05:15","2023-09-22 05:30","2023-09-22 05:30","2023-09-23 05:15","2023-09-23 05:15","2023-09-24 05:15","2023-09-24 05:15","2023-09-25 05:00","2023-09-25 05:00","2023-09-26 05:00","2023-09-26 05:00","2023-09-27 05:00","2023-09-27 05:00", ...

# %% [markdown]
# # Plotly BarChart

# %%
# Grouped the countries get the mean temperature
grouped_data = weather.groupby(['country'])['temperature_celsius'].mean().reset_index()
# Get the counties which have low temperature
low_temp = grouped_data.query('temperature_celsius < 13')

# %%
# Counties Temperatures Below 13°C degree
barchart = px.bar(low_temp, x="country", y="temperature_celsius", title="Temperatures Below 13°C", color="country", height=600)
barchart.update_xaxes(title="Country")
barchart.update_yaxes(title="Mean Temperature (°C)")

# Add data labels on top of bars
barchart.update_traces(texttemplate="%{y:.2f}°C", textposition="outside")
# Add interactive legends
barchart.update_layout(showlegend=True)
# Customize color palette
barchart.update_traces(marker=dict(line=dict(color='rgb(0,0,0)', width=0.3)))
# Customize hover information
barchart.update_traces(hovertemplate="<b>%{x}</b><br>Mean Temperature: %{y:.2f}°C")
# Customize the legend title
barchart.update_layout(legend_title_text='Country')


barchart.show()
# Out:
# <div>                            <div id="9c9c1519-5c3b-4ecd-b82b-8d2cc17dba05" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c9c1519-5c3b-4ecd-b82b-8d2cc17dba05")) {                    Plotly.newPlot(                        "9c9c1519-5c3b-4ecd-b82b-8d2cc17dba05",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"outside","x":["Afghanistan"],"xaxis":"x","y":[5.635263157894737],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Andorra","marker":{"color":"#EF553B","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"outside","x":["Andorra"],"xaxis":"x","y":[2.656315789473684],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Armenia","marker":{"color":"#00cc96","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"outside","x":["Armenia"],"xaxis":"x","y":[8.51421052631579],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Australia","marker":{"color":"#ab63fa","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"outside","x":["Australia"],"xaxis":"x","y":[12.898947368421053],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Austria","marker":{"color":"#FFA15A","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"outside","x":["Austria"],"xaxis":"x","y":[9.198947368421052],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Azerbaijan","marker":{"color":"#19d3f3","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Azerbaijan","offsetgroup":"Azerbaijan","orientation":"v","showlegend":true,"textposition":"outside","x":["Azerbaijan"],"xaxis":"x","y":[12.00842105263158],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Belarus","marker":{"color":"#FF6692","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Belarus","offsetgroup":"Belarus","orientation":"v","showlegend":true,"textposition":"outside","x":["Belarus"],"xaxis":"x","y":[2.607894736842105],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}°C"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eMean Temperature: %{y:.2f}°C","legendgroup":"Belgium","marker":{"color":"#B6E880","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Belgium","offsetgroup":"Belgium","orientation":"v ...

# %%
# Counties Weather Condition
barchart = px.histogram(weather, x="condition_text", title="Weather Condition", color="condition_text", height=600, width=1200)
barchart.update_xaxes(title="Weather Condition")
barchart.update_yaxes(title="Count")

# Add data labels on top of bars
barchart.update_traces(texttemplate="Count %{y:2f}", textposition="outside")
# Add interactive legends
barchart.update_layout(showlegend=True)
# Customize color palette
barchart.update_traces(marker=dict(line=dict(color='rgb(0,0,0)', width=0.3)))
# Customize hover information
barchart.update_traces(hovertemplate="<b>%{x}</b><br>Count: %{y:2f}")
# Customize the legend title
barchart.update_layout(legend_title_text="Weather Condition")

barchart.show()
# Out:
# <div>                            <div id="da16d9a0-2ebf-4011-a5f4-086480125bfe" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da16d9a0-2ebf-4011-a5f4-086480125bfe")) {                    Plotly.newPlot(                        "da16d9a0-2ebf-4011-a5f4-086480125bfe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount: %{y:2f}","legendgroup":"Sunny","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"color":"rgb(0,0,0)","width":0.3}},"name":"Sunny","offsetgroup":"Sunny","orientation":"v","showlegend":true,"x":["Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny","Sunny ...

# %% [markdown]
# # Plotly Sunburst Chart

# %%
zone = ['Asia/Kabul', 'Europe/Tirane', 'Africa/Algiers', 'Europe/Andorra','Africa/Luanda', 'America/Antigua','America/Argentina/Buenos_Aires','Australia/Sydney', 
        'Europe/Vienna','Asia/Bahrain', 'Asia/Dhaka','Europe/Brussels', 'America/Belize','America/Manaus', 'Asia/Brunei','Africa/Ouagadougou','Atlantic/Cape_Verde',
        'Asia/Phnom_Penh', 'Africa/Douala', "Asia/Bangkok"]

# %%
weather_zones = weather.query("timezone in @zone")
# Create the Sunburst chart
fig = px.sunburst(
    weather_zones, 
    path=['timezone', 'country'], # Define the hierarchical path
    values='temperature_celsius', # Add values
    height=600,
    color='temperature_celsius',  # Color based on temperature
    color_continuous_scale='thermal', # Use the Temps color scale
    color_continuous_midpoint=np.mean(weather_zones['temperature_celsius']), # Set color midpoint to the median temperature
    labels={'temperature_celsius': 'Temperature (°C)'},  # Customize the colorbar label
)

# Set title
fig.update_layout(
    title="Average Temperature by Time Zone and Country",
)

fig.show()
# Out:
# <div>                            <div id="510d920a-0f0e-48e5-98ac-ed39a2f15e49" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("510d920a-0f0e-48e5-98ac-ed39a2f15e49")) {                    Plotly.newPlot(                        "510d920a-0f0e-48e5-98ac-ed39a2f15e49",                        [{"branchvalues":"total","customdata":[[13.516213691977216],[15.403397649324079],[19.073413557011175],[13.922904695858925],[26.583958362470277],[28.419455065147194],[25.101127827928227],[14.212298025134649],[13.614452454514247],[26.293252333305308],[23.00494316184226],[12.724403243181946],[28.83684229905373],[33.6281322827655],[26.030509505086943],[31.27808631935765],[27.013213811420982],[22.348460194659346],[26.97671533132412],[29.623313528005216],[24.815347815687044],[21.88567161156397],[19.073413557011175],[26.563681592039803],[26.583958362470277],[31.27808631935765],[28.419455065147194],[25.101127827928227],[28.83684229905373],[33.6281322827655],[26.293252333305308],[23.935125802427816],[26.030509505086943],[23.00494316184226],[13.516213691977216],[27.013213811420982],[26.97671533132412],[14.212298025134649],[13.922904695858925],[12.724403243181946],[15.403397649324079],[13.614452454514247]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003etemperature_celsius_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eTemperature (°C)=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Asia\u002fKabul\u002fAfghanistan","Europe\u002fTirane\u002fAlbania","Africa\u002fAlgiers\u002fAlgeria","Europe\u002fAndorra\u002fAndorra","Africa\u002fLuanda\u002fAngola","America\u002fAntigua\u002fAntigua and Barbuda","America\u002fArgentina\u002fBuenos_Aires\u002fArgentina","Australia\u002fSydney\u002fAustralia","Europe\u002fVienna\u002fAustria","Asia\u002fBahrain\u002fBahrain","Asia\u002fDhaka\u002fBangladesh","Europe\u002fBrussels\u002fBelgium","America\u002fBelize\u002fBelize","America\u002fManaus\u002fBrazil","Asia\u002fBrunei\u002fBrunei Darussalam","Africa\u002fOuagadougou\u002fBurkina Faso","Asia\u002fPhnom_Penh\u002fCambodia","Africa\u002fDouala\u002fCameroon","Atlantic\u002fCape_Verde\u002fCape Verde","Africa\u002fDouala\u002fChad","Asia\u002fBangkok\u002fThailand","Asia\u002fBangkok\u002fVietnam","Africa\u002fAlgiers","Africa\u002fDouala","Africa\u002fLuanda","Africa\u002fOuagadougou","America\u002fAntigua","America\u002fArgentina\u002fBuenos_Aires","America\u002fBelize","America\u002fManaus","Asia\u002fBahrain","Asia\u002fBangkok","Asia\u002fBrunei","Asia\u002fDhaka","Asia\u002fKabul","Asia\u002fPhnom_Penh","Atlantic\u002fCape_Verde","Australia\u002fSydney","Europe\u002fAndorra","Europe\u002fBrussels","Europe\u002fTirane","Europe\u002fVienna"],"labels":["Afghanistan","Albania","Algeria","Andorra","Angola","Antigua and Barbuda","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Belize","Brazil","Brunei Darussalam","Burkina Faso","Cambodia","Cameroon","Cape Verde","Chad","Thailand","Vietnam","Africa\u002fAlgiers","Africa\u002fDouala","Africa\u002fLuanda","Africa\u002fOuagadougou","America\u002fAntigua","America\u002fArgentina\u002fBuenos_Aires","America\u002fBelize","America\u002fManaus","Asia\u002fBahrain","Asia\u002fBangkok","Asia\u002fBrunei","Asia\u002fDhaka","Asia\u002fKabul","Asia\u002fPhnom_Penh","Atlantic\u002fCape_Verde","Australia\u002fSydney","Europe\u002fAndorra","Europe\u002fBrussels","Europe\u002fTirane","Europe\u002fVienna"],"marker":{"coloraxis":"coloraxis","colors":[13.516213691977216,15.403397649324079,19.073413557011175,13.922904695858925,26.583958362470277,28.419455065147194,25.101127827928227,14.212298025134649,13.614452454514247,26.293252333305308,23.00494316184226,12.724403243181946,28.83684229905373,33.628132282 ...

# %% [markdown]
# # Plotly Polar Chart

# %%
fig = px.scatter_polar(
    weather_zones,
    r="wind_kph", # Radial distance represents wind speed in kilometers per hour
    theta="wind_direction", # Angular position represents wind direction
    color="temperature_celsius", # Color represents temperature in degrees Celsius
    color_continuous_scale = "viridis", # Use viridis color scale
    title="Wind Speed and Wind Direction",
    labels={'temperature_celsius': 'Temperature (°C)'}, # Customize the colorbar label
    height=600, # Add height to the polar chart
    hover_name="location_name", # Add location names as hover text
)

fig.show()
# Out:
# <div>                            <div id="d18875f6-25c1-44aa-918d-ee469338a1db" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d18875f6-25c1-44aa-918d-ee469338a1db")) {                    Plotly.newPlot(                        "d18875f6-25c1-44aa-918d-ee469338a1db",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ewind_kph=%{r}\u003cbr\u003ewind_direction=%{theta}\u003cbr\u003eTemperature (°C)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'djamena","Nan","'S-Gravenwezel","Bangkok","Hanoi","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Canberra","Vienna","Manama","Dhaka","Brussels","Belmopan","Bras","Bandar Seri Begawan","Ouagadougou","Praia","Phnom Penh","Bafoussam","N'dj ...

# %% [markdown]
# # Plotly Scatter Plot

# %%
fig = px.scatter(
    weather_zones,
    x="temperature_celsius",
    y="humidity",
    color="temperature_celsius", 
    color_continuous_scale = "tempo",
    size='wind_kph', # Size of data points based on wind speed in kph
    hover_name='country', # Add hover value
    hover_data=['location_name'],  # Additional data to show on hover (location_name)
    labels=
        {
            'temperature_celsius': 'Temperature (°C)',
            'humidity': 'Humidity',
            'wind_kph': 'Wind speed (kph)',
            'country': 'Country',
            'condition_text': 'Weather Condition',
            'location_name': 'City'
        },
    title="Temperature and Humidity with Wind Speed",
    height=600,
    )

fig.update_xaxes(title="Temperature (°C)")
fig.update_yaxes(title="Humidity")


fig.show()
# Out:
# <div>                            <div id="ae90848b-2ad3-46b9-ae6a-695e3d96f092" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae90848b-2ad3-46b9-ae6a-695e3d96f092")) {                    Plotly.newPlot(                        "ae90848b-2ad3-46b9-ae6a-695e3d96f092",                        [{"customdata":[["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"],["Bafoussam"],["N'djamena"],["Nan"],["'S-Gravenwezel"],["Bangkok"],["Hanoi"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Canberra"],["Vienna"],["Manama"],["Dhaka"],["Brussels"],["Belmopan"],["Bras"],["Bandar Seri Begawan"],["Ouagadougou"],["Praia"],["Phnom Penh"], ...

# %% [markdown]
# # Plotly Pie Chart

# %%
# Group the weather condition and calculate the mean of temperature
weather_status = weather_zones.groupby('condition_text')['temperature_celsius'].agg(['mean']).reset_index()
# Rename the columns
weather_status = weather_status.rename(columns={'mean': 'temperature'})
weather_status
# Out:
#                                  condition_text  temperature
# 0                                         Clear    18.283963
# 1                                        Clear     15.339496
# 2                                        Cloudy    22.611765
# 3                                       Cloudy     23.325000
# 4                                           Fog    15.755000
# 5                                  Freezing fog    -1.340000
# 6                                    Heavy rain    17.000000
# 7                                    Heavy snow    -0.854545
# 8                                 Light drizzle    12.766667
# 9                           Light freezing rain    -0.760000
# 10                                   Light rain    17.958667
# 11                            Light rain shower    24.196721
# 12                                  Light sleet     4.100000
# 13                                   Light snow    -0.025000
# 14                           Light snow showers    -0.300000
# 15                                         Mist    18.996923
# 16                Moderate or heavy rain shower    23.883333
# 17          Moderate or heavy rain with thunder    23.030303
# 18                      Moderate or heavy sleet     4.000000
# 19  Moderate or heavy snow in area with thunder    -0.800000
# 20               Moderate or heavy snow showers    -0.962500
# 21                                Moderate rain    14.733333
# 22                       Moderate rain at times    16.000000
# 23                                Moderate snow    -2.557143
# 24                                     Overcast    20.936364
# 25                                    Overcast     10.740000
# 26                               Partly Cloudy     19.508000
# 27                                Partly cloudy    23.456747
# 28                            Patchy heavy snow    -3.450000
# 29                         Patchy light drizzle    17.260000
# 30                            Patchy light rain    14.770000
# 31               Patchy light rain with thunder    25.700000
# 32                            Patchy light snow    -1.450000
# 33                         Patchy moderate snow    -0.583333
# 34                           Patchy rain nearby    27.162857
# 35                         Patchy rain possible    21.552846
# 36                           Patchy snow nearby    -4.300000
# 37                         Patchy snow possible    -7.200000
# 38                                        Sunny    24.785088
# 39                 Thundery outbreaks in nearby    32.400000
# 40                  Thundery outbreaks possible    17.350000
# 41                       Torrential rain shower    22.400000

# %%
fig = px.pie(
    weather_status,
    names='condition_text',
    values='temperature',
    title='Weather Condition And Temperature',
    height=600,
    labels=(
        {
            'condition_text': 'Weather Condition',
            'temperature': 'Temperature (°C)'
        }
    )
)

# Add labels inside the pie chart section
fig.update_traces(textposition='inside', textinfo='label+percent')

fig.show()
# Out:
# <div>                            <div id="07a62d97-dc7e-4f97-9eae-fa15c34b6c6d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07a62d97-dc7e-4f97-9eae-fa15c34b6c6d")) {                    Plotly.newPlot(                        "07a62d97-dc7e-4f97-9eae-fa15c34b6c6d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Weather Condition=%{label}\u003cbr\u003eTemperature (°C)=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Clear","Clear ","Cloudy","Cloudy ","Fog","Freezing fog","Heavy rain","Heavy snow","Light drizzle","Light freezing rain","Light rain","Light rain shower","Light sleet","Light snow","Light snow showers","Mist","Moderate or heavy rain shower","Moderate or heavy rain with thunder","Moderate or heavy sleet","Moderate or heavy snow in area with thunder","Moderate or heavy snow showers","Moderate rain","Moderate rain at times","Moderate snow","Overcast","Overcast ","Partly Cloudy ","Partly cloudy","Patchy heavy snow","Patchy light drizzle","Patchy light rain","Patchy light rain with thunder","Patchy light snow","Patchy moderate snow","Patchy rain nearby","Patchy rain possible","Patchy snow nearby","Patchy snow possible","Sunny","Thundery outbreaks in nearby","Thundery outbreaks possible","Torrential rain shower"],"legendgroup":"","name":"","showlegend":true,"values":[18.28396299151889,15.339495798319328,22.61176470588235,23.325,15.755,-1.34,17.0,-0.8545454545454544,12.766666666666667,-0.76,17.95866666666667,24.19672131147541,4.1,-0.025000000000000022,-0.3,18.996923076923075,23.883333333333336,23.03030303030303,4.0,-0.8,-0.9624999999999999,14.733333333333334,16.0,-2.557142857142857,20.936363636363637,10.74,19.508,23.45674720094284,-3.45,17.259999999999998,14.77,25.7,-1.4500000000000002,-0.5833333333333334,27.162857142857145,21.552845528455286,-4.3,-7.2,24.785087719298247,32.4,17.35,22.4],"type":"pie","textinfo":"label+percent","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111 ...

# %%
# Group the moon phases and calculate the mean of moon illumination
weather_zones_moon = weather_zones.groupby('moon_phase')['moon_illumination'].agg(['mean']).reset_index()
# Rename the columns
weather_zones_moon = weather_zones_moon.rename(columns={'mean': 'moon_illumination'})
weather_zones_moon
# Out:
#         moon_phase  moon_illumination
# 0    First Quarter          44.342657
# 1        Full Moon          99.223256
# 2     Last Quarter          55.419162
# 3         New Moon           0.873684
# 4  Waning Crescent          23.750250
# 5   Waning Gibbous          85.972407
# 6  Waxing Crescent          13.515801
# 7   Waxing Gibbous          79.037415

# %%
fig = px.pie(
    weather_zones_moon,
    names='moon_phase',
    values='moon_illumination',
    title='Moon Phase and Moon Illumination',
    height=600,
    hole=0.4,
    labels=(
        {
            'moon_phase': 'Moon Phase',
            'moon_illumination': 'Moon Illumination (%)'
        }
    ),
)

# Add labels inside the pie chart section
fig.update_traces(textposition='inside', textinfo='label+percent')

fig.show()
# Out:
# <div>                            <div id="82405cf7-28f4-4534-8ac3-11593c996a15" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82405cf7-28f4-4534-8ac3-11593c996a15")) {                    Plotly.newPlot(                        "82405cf7-28f4-4534-8ac3-11593c996a15",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Moon Phase=%{label}\u003cbr\u003eMoon Illumination (%)=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["First Quarter","Full Moon","Last Quarter","New Moon","Waning Crescent","Waning Gibbous","Waxing Crescent","Waxing Gibbous"],"legendgroup":"","name":"","showlegend":true,"values":[44.34265734265734,99.22325581395349,55.41916167664671,0.8736842105263158,23.75024975024975,85.97240723120838,13.515801354401805,79.0374149659864],"type":"pie","textinfo":"label+percent","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","w ...

# %% [markdown]
# # Plotly Gauge Chart

# %%
temperature_max = weather['temperature_celsius'].max()
temperature_min = weather['temperature_celsius'].min()
temperature_mean = weather['temperature_celsius'].mean()

# %%
fig = go.Figure(go.Indicator(
    mode="gauge+number", # Set the chart mode to gauge with a number
    value= temperature_mean, # Set the value 
    title={'text' : 'Temperature (°C)'},  # Set the title of the gauge chart
    gauge= { 'axis' : {'range' : [None, temperature_max]}, # Define the gauge axis range
            'steps' : [
                {'range' : [0, 10], 'color' : "seashell"}, # Define seashell color ranges for the gauge
                {'range' : [10, 20], 'color' : "lightblue"}, # Define lightblue color ranges for the gauge
                {'range' : [20, 30], 'color' : "sandybrown"}, # Define sandybrown color ranges for the gauge
                {'range' : [30, temperature_max], 'color' : "tomato"} # Define tomato color ranges for the gauge
            ],
            'threshold' : {
                'line' : {'color' : 'red', 'width' : 4}, # Define the threshold line's appearance
                'thickness' : 0.75, # Set the thickness of the threshold line
                'value' : temperature_mean # Set the value where the threshold line is located
            }
    }
))

fig.update_layout(
    title = "Temperature Status", # Define the title
    height=400 # Define the height
)

fig.show()
# Out:
# <div>                            <div id="c3322220-cfd6-4204-bde7-f2d7f510946e" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3322220-cfd6-4204-bde7-f2d7f510946e")) {                    Plotly.newPlot(                        "c3322220-cfd6-4204-bde7-f2d7f510946e",                        [{"gauge":{"axis":{"range":[null,45.4]},"steps":[{"color":"seashell","range":[0,10]},{"color":"lightblue","range":[10,20]},{"color":"sandybrown","range":[20,30]},{"color":"tomato","range":[30,45.4]}],"threshold":{"line":{"color":"red","width":4},"thickness":0.75,"value":19.024817064938574}},"mode":"gauge+number","title":{"text":"Temperature (°C)"},"value":19.024817064938574,"type":"indicator"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"sca ...

# %% [markdown]
# # Plotly MapBox Chart

# %%
fig = px.scatter_mapbox(
    weather,
    lat="latitude",  # Latitude data column
    lon="longitude", # Longitude data column 
    color="temperature_celsius", # Color data for points
    color_continuous_scale=px.colors.cyclical.IceFire, # Color scale
    hover_name= 'location_name', # Add hover value
    size="humidity", # Based on size data will change
    size_max=7,  # Maximum size for points
    labels=( 
        {
            'latitude': 'Latitude',
            'longitude': 'Longitude',
            'temperature_celsius' : 'Temperature (°C)',
            'humidity': 'Humidity'
        }),
    height=600,
    width=1000
    )

fig.update_layout(
    mapbox_style='open-street-map', # Map style
    title="Temperature and Humidity ",  # Title of the map
    hovermode='closest',  # Hover mode for interactivity
    mapbox=dict(
        bearing=0, # Bearing of the map
        center=go.layout.mapbox.Center(
            lat=47, # Center latitude
            lon=12 # Center longitude
        ),
        pitch=0, # Map pitch
        zoom=4 # Initial map zoom level
    )
)

fig.show()
# Out:
# <div>                            <div id="293fddb4-69d1-4fb2-b135-aaebb4ac02da" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("293fddb4-69d1-4fb2-b135-aaebb4ac02da")) {                    Plotly.newPlot(                        "293fddb4-69d1-4fb2-b135-aaebb4ac02da",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eHumidity=%{marker.size}\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cbr\u003eTemperature (°C)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Yerevan","Canberra","Vienna","Baku","Nassau","Manama","Dhaka","Bridgetown","Minsk","Brussels","Belmopan","Porto-Novo","Thimphu","Sucre","Sarajevo","Gaborone","Bras","Bandar Seri Begawan","Sofia","Ouagadougou","Bujumbura","Ivory","Praia","Phnom Penh","Bafoussam","Ottawa","Bangui","N'djamena","Santiago","Beijing","Bogot","Moroni","Brazzaville","San Juan","Zagreb","Havana","Nicosia","Prague","Kinshasa","Copenhagen","Djibouti","Roseau","Santo Domingo","Quito","Cairo","San Salvador","Malabo","Asmara","Tallinn","Mbabane","Addis Ababa","Suva","Helsinki","Paris","Libreville","Banjul","Tbilisi","Berlin","Accra","Athens","Saint George's","Guatemala City","Conakry","Bissau","Georgetown","Port-Au-Prince","Vatican City","Tegucigalpa","Budapest","Hella","New Delhi","Jakarta","Tehran","Baghdad","Dublin","Jerusalem","Rome","Norman Gardens","Tokyo","Amman","Astana","Nairobi","Tarawa","Kuwait City","Bishkek","Laos","Riga","Beirut","Maseru","Monrovia","Nan","Vaduz","Vilnius","Luxembourg","Antananarivo","Lilongwe","Kuala Lumpur","Farukolhufunadhoo","Bamako","Valletta","Majuro","Nouakchott","Port Louis","Mexico City","Palikir","Chi-Chi-Erh","Monaco","Ulaanbaatar","Podgorica","Rabat","Maputo","Pathein","Windhoek","Yaren","Kathmandu","Amsterdam","Wellington","Managua","Niamey","Abuja","Pyongyang","Skopje","Oslo","Muscat","Islamabad","Adkip","National","Panama City","Port Moresby","Carreria","Lima","Manila","Warsaw","Lisbon","Doha","Bucharest","Moscow","Kigali","Basseterre","Castries","Kingstown","Apia","San Marino","'S-Gravenwezel","Riyadh","Dakar","Belgrade","Victoria","Freetown","Singapore","Bratislava","Ljubljana","Honiara","Mogadishu","Pretoria","Seoul","Juba","Madrid","Colombo","Khartoum","Paramaribo","Stockholm","Bern","Damascus","Dushanbe","Dodoma","Bangkok","Murong Timor","Lom","Nuku`Aloia","Port Of Spain","Tunis","Ankara","Ashgabat","Funafuti","Kampala","Lviv","Abu Dhabi","London","Washington Park","Montevideo","Tashkent","Port Vila","Caracas","Hanoi","Sanaa","Lusaka","Harare","Kabul","Tirana","Algiers","Andorra La Vella","Luanda","Saint John's","Buenos Aires","Yerevan","Canberra","Vienna","Baku","Nassau","Manama","Dhaka","Bridgetown","Minsk","Brussels","Belmopan","Porto-Novo","Thimphu","Sucre","Sarajevo","Gaborone","Bras","Bandar Seri Begawan","Sofia","Ouagadougou","Bujumbura","Ivory","Praia","Phnom Penh","Bafoussam","Ottawa","Bangui","N'djamena","Santiago","Beijing","Bogot","Moroni","Brazzaville","San Juan","Zagreb","Havana","Nicosia","Prague","Kinshasa","Copenhagen","Djibouti","Roseau","Santo Domingo","Quito","Cairo","San Salvador","Malabo","Asmara","Tallinn","Mbabane","Addis Ababa","Suva","Helsinki","Paris","Libreville","Banjul","Tbilisi","Berlin","Accra","Athens","Saint George's","Guatemala City","Conakry","Bissau","Georgetown","Port-Au-Prince","Vatican City","Tegucigalpa","Budapest","Hella","New Delhi","Jakarta","Tehran","Baghdad","Dublin","Jerusalem","Rome","Norman Gardens","Tokyo","Amman","Astana","Nairobi","Tarawa","Kuwait City","Bishkek","Laos","Riga","Beirut","Maseru","Monrovia","Nan","Vaduz","Vilnius","Luxembourg","Antananarivo","Lilongwe","Kuala Lumpur" ...
